# %%
# !git clone https://github.com/priiyaanjaalii0611/ASL_to_English.git
# Out:
# Cloning into 'ASL_to_English'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 86 (delta 4), reused 3 (delta 3), pack-reused 79
# Receiving objects: 100% (86/86), 169.99 MiB | 19.48 MiB/s, done.
# Resolving deltas: 100% (39/39), done.
# Updating files: 100% (59/59), done.

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.236 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.6/78.2 GB disk)

# %%
from ultralytics import YOLO

model = YOLO('yolov8n-cls.pt')  # load a pretrained YOLOv8n classification model
model.train(data='/content/mask_data', epochs=12)  # train the model
#model('/content/data/with_mask/with_mask_1002.jpg')  # predict on an image
# Out:
# Ultralytics YOLOv8.0.236 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=/content/runs/classify/train5/weights/ihsan_mask.pt source='/content/mask.mp4'
# Out:
# Ultralytics YOLOv8.0.236 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
#
# video 1/1 (1/258) /content/mask.mp4: 224x224 with_mask 1.00, without_mask 0.00, 4.0ms
# video 1/1 (2/258) /content/mask.mp4: 224x224 with_mask 1.00, without_mask 0.00, 2.9ms
# video 1/1 (3/258) /content/mask.mp4: 224x224 with_mask 1.00, without_mask 0.00, 2.5ms
# video 1/1 (4/258) /content/mask.mp4: 224x224 with_mask 1.00, without_mask 0.00, 2.5ms
# video 1/1 (5/258) /content/mask.mp4: 224x224 with_mask 1.00, without_mask 0.00, 2.4ms
# video 1/1 (6/258) /content/mask.mp4: 224x224 with_mask 1.00, without_mask 0.00, 2.5ms
# video 1/1 (7/258) /content/mask.mp4: 224x224 with_mask 1.00, without_mask 0.00, 2.5ms
# video 1/1 (8/258) /content/mask.mp4: 224x224 with_mask 1.00, without_mask 0.00, 2.5ms
# video 1/1 (9/258) /content/mask.mp4: 224x224 with_mask 1.00, without_mask 0.00, 2.6ms
# ...

# %%
# !yolo predict model=/content/runs/classify/train5/weights/ihsan_mask.pt source='/content/with_mask_296.jpg'
# Out:
# Ultralytics YOLOv8.0.236 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
#
# image 1/1 /content/with_mask_296.jpg: 224x224 with_mask 1.00, without_mask 0.00, 4.2ms
# Speed: 10.7ms preprocess, 4.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict8
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
d=plt.imread('/content/runs/classify/predict8/with_mask_296.jpg')
plt.imshow(d)

# %%
d=plt.imread('/content/runs/classify/predict6/with_mask_3705.jpg')
plt.imshow(d)

# %%
import zipfile
import os

# Specify the path to your zip file
zip_file_path = '/content/mask_data.zip'

# Specify the directory where you want to extract the contents
extracted_folder_path = '/content/'

# Create the target directory if it doesn't exist
os.makedirs(extracted_folder_path, exist_ok=True)

# Open the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # Extract all the contents into the specified directory
    zip_ref.extractall(extracted_folder_path)

print(f"Zip file '{zip_file_path}' has been extracted to '{extracted_folder_path}'.")
# Out:
# Zip file '/content/mask_data.zip' has been extracted to '/content/'.

# %%
import matplotlib.pyplot as plt

# %%
d=plt.imread("/content/image.jpg")

# %%
plt.imshow(d)

# %%
print("xhr de rana orede hum tha sa hkole jana eee ")
# Out:
# xhr de rana orede hum tha sa hkole jana eee

# %%
j=0
for i in range(10,10):
    j=j+1
    print(i,"*",j)

# %%
a="basit"
b=" ali"
c=a+b
print(c)
# Out:
# basit ali

# %%
q=print(c[4])
f=print(c[6])
# Out:
# t
# a

# %%
print(2)
# Out:
# 2

# %%
# Out:
# basiti
